# %%
import os
import pandas as pd

# %%
file = os.path.join("resources/2017.csv")

# %%
data = pd.read_csv(file)

# %%
data
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1   Álex Abrines\abrinal01  SG   24  OKC  75   8  1134  115  291  ...
# 1      2       Quincy Acy\acyqu01  PF   27  BRK  70   8  1359  130  365  ...
# 2      3   Steven Adams\adamsst01   C   24  OKC  76  76  2487  448  712  ...
# 3      4    Bam Adebayo\adebaba01   C   20  MIA  69  19  1368  174  340  ...
# 4      5  Arron Afflalo\afflaar01  SG   32  ORL  53   3   682   65  162  ...
# ..   ...                      ...  ..  ...  ...  ..  ..   ...  ...  ...  ...
# 659  537   Tyler Zeller\zellety01   C   28  BRK  42  33   703  125  229  ...
# 660  537   Tyler Zeller\zellety01   C   28  MIL  24   1   406   62  105  ...
# 661  538    Paul Zipser\zipsepa01  SF   23  CHI  54  12   824   81  234  ...
# 662  539     Ante Žižić\zizican01   C   21  CLE  32   2   214   49   67  ...
# 663  540    Ivica Zubac\zubaciv01   C   20  LAL  43   0   410   61  122  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0    0.848   26   88  114   28   38    8   25  124   353
# 1    0.817   40  217  257   57   33   29   60  149   411
# 2    0.559  384  301  685   88   92   78  128  215  1056
# 3    0.721  118  263  381  101   32   41   66  138   477
# 4    0.846    4   62   66   30    4    9   21   56   179
# ..     ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 659  0.667   63  131  194   28    8   21   35   78   300
# 660  0.895   47   64  111   19    7   14   12   48   141
# 661  0.760   13  118  131   46   20   15   43   86   218
# 662  0.724   24   36   60    5    2   13   11   30   119
# 663  0.765   45   78  123   25    8   15   26   47   161
#
# [664 rows x 30 columns]

# %%
# reading csv file from url  
# dropping null value columns to avoid errors 
data.dropna(inplace = True) 
  
# new data frame with split value columns 
new = data["Player"].str.split("\\", n = 1, expand = True)  
  
# making separate first name column from new data frame 
data["Name"]= new[0] 
  
# df display 
data
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  \
# 0      1   Álex Abrines\abrinal01  SG   24  OKC  75   8  1134  115  291  ...
# 1      2       Quincy Acy\acyqu01  PF   27  BRK  70   8  1359  130  365  ...
# 2      3   Steven Adams\adamsst01   C   24  OKC  76  76  2487  448  712  ...
# 3      4    Bam Adebayo\adebaba01   C   20  MIA  69  19  1368  174  340  ...
# 4      5  Arron Afflalo\afflaar01  SG   32  ORL  53   3   682   65  162  ...
# ..   ...                      ...  ..  ...  ...  ..  ..   ...  ...  ...  ...
# 658  537   Tyler Zeller\zellety01   C   28  TOT  66  34  1109  187  334  ...
# 659  537   Tyler Zeller\zellety01   C   28  BRK  42  33   703  125  229  ...
# 660  537   Tyler Zeller\zellety01   C   28  MIL  24   1   406   62  105  ...
# 661  538    Paul Zipser\zipsepa01  SF   23  CHI  54  12   824   81  234  ...
# 663  540    Ivica Zubac\zubaciv01   C   20  LAL  43   0   410   61  122  ...
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS           Name
# 0     26   88  114   28   38    8   25  124   353   Álex Abrines
# 1     40  217  257   57   33   29   60  149   411     Quincy Acy
# 2    384  301  685   88   92   78  128  215  1056   Steven Adams
# 3    118  263  381  101   32   41   66  138   477    Bam Adebayo
# 4      4   62   66   30    4    9   21   56   179  Arron Afflalo
# ..   ...  ...  ...  ...  ...  ...  ...  ...   ...            ...
# 658  110  195  305   47   15   35   47  126   441   Tyler Zeller
# 659   63  131  194   28    8   21   35   78   300   Tyler Zeller
# 660   47   64  111   19    7   14   12   48   141   Tyler Zeller
# 661   13  118  131   46   20   15   43   86   218    Paul Zipser
# 663   45   78  123   25    8   15   26   47   161    Ivica Zubac
#
# [561 rows x 31 columns]

# %%
#Drop duplicates for traded players
clean_stats = data.drop_duplicates(subset=['Name'], keep='first')
#clean_stats

# %%
#Drop players under 500 minutes played
clean_stats = clean_stats.loc[clean_stats['MP'] > 499]
#clean_stats

# %%
#Column check for cleanup
#list(clean_stats)

# %%
#Clean for columns
df = clean_stats[['Name', 'Pos', 'Age', 'Tm', 'PTS', 'TRB', 'AST', '3P', 'FG%', 'FT%', 'STL', 'BLK', 'TOV']]

#Clean for position
guards = df.loc[(df['Pos'] == 'PG') | (df['Pos'] == 'SG')]
forwards = df.loc[(df['Pos'] == 'SF') | (df['Pos'] == 'PF')]
centers = df.loc[df['Pos'] == 'C']

# %%
#df['zscore'] = (df.a - df.a.mean())/df.a.std(ddof=0)
guards['PTS Z'] = (guards['PTS'] - guards['PTS'].mean())/guards['PTS'].std(ddof=0)
guards['TRB Z'] = (guards['TRB'] - guards['TRB'].mean())/guards['TRB'].std(ddof=0)
guards['AST Z'] = (guards['AST'] - guards['AST'].mean())/guards['AST'].std(ddof=0)
guards['3P Z'] = (guards['3P'] - guards['3P'].mean())/guards['3P'].std(ddof=0)
guards['FG% Z'] = (guards['FG%'] - guards['FG%'].mean())/guards['FG%'].std(ddof=0)
guards['FT% Z'] = (guards['FT%'] - guards['FT%'].mean())/guards['FT%'].std(ddof=0)
guards['STL Z'] = (guards['STL'] - guards['STL'].mean())/guards['STL'].std(ddof=0)
guards['BLK Z'] = (guards['BLK'] - guards['BLK'].mean())/guards['BLK'].std(ddof=0)
guards['TOV Z'] = (guards['TOV'] - guards['TOV'].mean())/guards['TOV'].std(ddof=0)
guards
# Out:
# <ipython-input-10-76e0b29de625>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards['PTS Z'] = (guards['PTS'] - guards['PTS'].mean())/guards['PTS'].std(ddof=0)
# <ipython-input-10-76e0b29de625>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards['TRB Z'] = (guards['TRB'] - guards['TRB'].mean())/guards['TRB'].std(ddof=0)
# <ipython-input-10-76e0b29de625>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards['AST Z'] = (guards['AST'] - guards['AST'].mean())/guards['AST'].std(ddof=0)
# <ipython-input-10-76e0b29de625>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards['3P Z'] = (guards['3P'] - guards['3P'].mean())/guards['3P'].std(ddof=0)
# <ipython-input-10-76e0b29de625>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards['FG% Z'] = (guards['FG%'] - guards['FG%'].mean())/guards['FG%'].std(ddof=0)
# <ipython-input-10-76e0b29de625>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards['FT% Z'] = (guards['FT%'] - guards['FT%'].mean())/guards['FT%'].std(ddof=0)
# <ipython-input-10-76e0b29de625>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards['STL Z'] = (guards['STL'] - guards['STL'].mean())/guards['STL'].std(ddof=0)
# <ipython-input-10-76e0b29de625>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards['BLK Z'] = (guards['BLK'] - guards['BLK'].mean())/guards['BLK'].std(ddof=0)
# <ipython-input-10-76e0b29de625>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards['TOV Z'] = (guards['TOV'] - guards['TOV'].mean())/guards['TOV'].std(ddof=0)
#               Name Pos  Age   Tm   PTS  TRB  AST   3P    FG%    FT%  ...  TOV  \
# 0     Álex Abrines  SG   24  OKC   353  114   28   84  0.395  0.848  ...   25
# 4    Arron Afflalo  SG   32  ORL   179   66   30   27  0.401  0.846  ...   21
# 25   D.J. Augustin  PG   30  ORL   766  160  287  114  0.452  0.868  ...  123
# 29    Dwayne Bacon  SG   22  CHO   175  124   38   11  0.375  0.800  ...   23
# 32      Lonzo Ball  PG   20  LAL   528  360  376   90  0.360  0.451  ...  136
# ..             ...  ..  ...  ...   ...  ...  ...  ...    ...    ...  ...  ...
# 635  C.J. Williams  SG   27  LAC   209   56   43   22  0.442  0.813  ...   20
# 637   Lou Williams  SG   31  LAC  1782  198  417  186  0.435  0.880  ...  234
# 651   Delon Wright  PG   25  TOR   555  198  200   56  0.465  0.829  ...   78
# 654      Joe Young  PG   25  IND   207   63   39   25  0.430  0.759  ...   26
# 655     Nick Young  SG   32  GSW   581  125   36  123  0.412  0.862  ...   39
#
#         PTS Z     TRB Z     AST Z      3P Z     FG% Z     FT% Z     STL Z  \
# 0   -0.827310 -0.723242 -1.237848 -0.048903 -0.899278  0.596372 -0.583981
# 4   -1.215663 -1.144118 -1.223894 -1.002047 -0.743521  0.575530 -1.672226
# 25   0.094470 -0.319903  0.569293  0.452751  0.580416  0.804798 -0.071865
# 29  -1.224590 -0.635560 -1.168075 -1.269595 -1.418469  0.096151 -1.288139
# 32  -0.436725  1.433746  1.190279  0.051427 -1.807863 -3.540875  1.016380
# ..        ...       ...       ...       ...       ...       ...       ...
# 635 -1.148705 -1.231800 -1.133188 -1.085656  0.320821  0.231628 -0.808031
# 637  2.362094  0.013290  1.476352  1.656721  0.139104  0.929853  0.920358
# 651 -0.376463  0.013290 -0.037739 -0.517114  0.917891  0.398368  0.504265
# 654 -1.153169 -1.170423 -1.161097 -1.035490  0.009306 -0.331121 -1.352154
# 655 -0.318434 -0.626792 -1.182029  0.603247 -0.457966  0.742270 -0.583981
#
#         BLK Z     TOV Z
# 0   -0.660165 -1.186979
# 4   -0.586916 -1.252159
# 25  -1.246160  0.409939
# 29  -1.099661 -1.219569
# 32   1.903561  0.621775
# ..        ...       ...
# 635 -0.293919 -1.268454
# 637  0.145577  2.218693
# 651  1.171068 -0.323340
# 654 -1.172911 -1.170684
# 655 -0.733415 -0.958848
#
# [159 rows x 22 columns]

# %%
forwards['PTS Z'] = (forwards['PTS'] - forwards['PTS'].mean())/forwards['PTS'].std(ddof=0)
forwards['TRB Z'] = (forwards['TRB'] - forwards['TRB'].mean())/forwards['TRB'].std(ddof=0)
forwards['AST Z'] = (forwards['AST'] - forwards['AST'].mean())/forwards['AST'].std(ddof=0)
forwards['3P Z'] = (forwards['3P'] - forwards['3P'].mean())/forwards['3P'].std(ddof=0)
forwards['FG% Z'] = (forwards['FG%'] - forwards['FG%'].mean())/forwards['FG%'].std(ddof=0)
forwards['FT% Z'] = (forwards['FT%'] - forwards['FT%'].mean())/forwards['FT%'].std(ddof=0)
forwards['STL Z'] = (forwards['STL'] - forwards['STL'].mean())/forwards['STL'].std(ddof=0)
forwards['BLK Z'] = (forwards['BLK'] - forwards['BLK'].mean())/forwards['BLK'].std(ddof=0)
forwards['TOV Z'] = (forwards['TOV'] - forwards['TOV'].mean())/forwards['TOV'].std(ddof=0)
forwards
# Out:
# <ipython-input-11-e57a78bea640>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forwards['PTS Z'] = (forwards['PTS'] - forwards['PTS'].mean())/forwards['PTS'].std(ddof=0)
# <ipython-input-11-e57a78bea640>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forwards['TRB Z'] = (forwards['TRB'] - forwards['TRB'].mean())/forwards['TRB'].std(ddof=0)
# <ipython-input-11-e57a78bea640>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forwards['AST Z'] = (forwards['AST'] - forwards['AST'].mean())/forwards['AST'].std(ddof=0)
# <ipython-input-11-e57a78bea640>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forwards['3P Z'] = (forwards['3P'] - forwards['3P'].mean())/forwards['3P'].std(ddof=0)
# <ipython-input-11-e57a78bea640>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forwards['FG% Z'] = (forwards['FG%'] - forwards['FG%'].mean())/forwards['FG%'].std(ddof=0)
# <ipython-input-11-e57a78bea640>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forwards['FT% Z'] = (forwards['FT%'] - forwards['FT%'].mean())/forwards['FT%'].std(ddof=0)
# <ipython-input-11-e57a78bea640>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forwards['STL Z'] = (forwards['STL'] - forwards['STL'].mean())/forwards['STL'].std(ddof=0)
# <ipython-input-11-e57a78bea640>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forwards['BLK Z'] = (forwards['BLK'] - forwards['BLK'].mean())/forwards['BLK'].std(ddof=0)
# <ipython-input-11-e57a78bea640>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forwards['TOV Z'] = (forwards['TOV'] - forwards['TOV'].mean())/forwards['TOV'].std(ddof=0)
#                 Name Pos  Age   Tm   PTS  TRB  AST   3P    FG%    FT%  ...  \
# 1         Quincy Acy  PF   27  BRK   411  257   57  102  0.356  0.817  ...
# 10   Al-Farouq Aminu  PF   27  POR   644  525   84  125  0.395  0.738  ...
# 11   Justin Anderson  SF   24  PHI   236   93   25   34  0.431  0.737  ...
# 12     Kyle Anderson  SF   24  SAS   585  396  202   19  0.527  0.712  ...
# 13     Ryan Anderson  PF   29  HOU   617  331   60  131  0.431  0.774  ...
# ..               ...  ..  ...  ...   ...  ...  ...  ...    ...    ...  ...
# 631   Andrew Wiggins  SF   22  MIN  1452  358  160  112  0.438  0.643  ...
# 638  Marvin Williams  PF   31  CHO   744  370   96  126  0.458  0.829  ...
# 645  Justise Winslow  PF   21  MIA   529  370  148   49  0.424  0.635  ...
# 656   Thaddeus Young  PF   29  IND   955  512  152   58  0.487  0.598  ...
# 661      Paul Zipser  SF   23  CHI   218  131   46   37  0.346  0.760  ...
#
#      TOV     PTS Z     TRB Z     AST Z      3P Z     FG% Z     FT% Z  \
# 1     60 -0.762955 -0.373463 -0.631676  0.423436 -1.968102  0.672095
# 10    79 -0.214721  1.449720 -0.369632  0.862706 -1.160435 -0.223547
# 11    16 -1.174719 -1.489142 -0.942247 -0.875275 -0.414896 -0.234884
# 12    94 -0.353544  0.572143  0.775597 -1.161756  1.573207 -0.518315
# 13    42 -0.278250  0.129953 -0.602560  0.977298 -0.414896  0.184594
# ..   ...       ...       ...       ...       ...       ...       ...
# 631  138  1.686453  0.313632  0.367973  0.614423 -0.269930 -1.300585
# 638   66  0.020573  0.395267 -0.253168  0.881805  0.144258  0.808142
# 645   77 -0.485308  0.395267  0.251509 -0.588795 -0.559862 -1.391283
# 656  105  0.517043  1.361282  0.290331 -0.416907  0.744831 -1.810761
# 661   43 -1.217072 -1.230631 -0.738435 -0.817979 -2.175196  0.025872
#
#         STL Z     BLK Z     TOV Z
# 1   -0.618757 -0.186385 -0.457225
# 10   0.871911  0.211422 -0.099963
# 11  -1.202062 -0.982000 -1.284568
# 12   2.038520  0.934709  0.182086
# 13  -0.910410 -0.475700 -0.795683
# ..        ...       ...       ...
# 631  1.260781  0.609230  1.009430
# 638  0.126577  0.139094 -0.344405
# 645  0.061765 -0.041728 -0.137569
# 656  2.686637  0.066765  0.388922
# 661 -1.040033 -0.692686 -0.776880
#
# [117 rows x 22 columns]

# %%
centers['PTS Z'] = (centers['PTS'] - centers['PTS'].mean())/centers['PTS'].std(ddof=0)
centers['TRB Z'] = (centers['TRB'] - centers['TRB'].mean())/centers['TRB'].std(ddof=0)
centers['AST Z'] = (centers['AST'] - centers['AST'].mean())/centers['AST'].std(ddof=0)
centers['3P Z'] = (centers['3P'] - centers['3P'].mean())/centers['3P'].std(ddof=0)
centers['FG% Z'] = (centers['FG%'] - centers['FG%'].mean())/centers['FG%'].std(ddof=0)
centers['FT% Z'] = (centers['FT%'] - centers['FT%'].mean())/centers['FT%'].std(ddof=0)
centers['STL Z'] = (centers['STL'] - centers['STL'].mean())/centers['STL'].std(ddof=0)
centers['BLK Z'] = (centers['BLK'] - centers['BLK'].mean())/centers['BLK'].std(ddof=0)
centers['TOV Z'] = (centers['TOV'] - centers['TOV'].mean())/centers['TOV'].std(ddof=0)
centers
# Out:
# <ipython-input-12-39d256dfe872>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centers['PTS Z'] = (centers['PTS'] - centers['PTS'].mean())/centers['PTS'].std(ddof=0)
# <ipython-input-12-39d256dfe872>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centers['TRB Z'] = (centers['TRB'] - centers['TRB'].mean())/centers['TRB'].std(ddof=0)
# <ipython-input-12-39d256dfe872>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centers['AST Z'] = (centers['AST'] - centers['AST'].mean())/centers['AST'].std(ddof=0)
# <ipython-input-12-39d256dfe872>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centers['3P Z'] = (centers['3P'] - centers['3P'].mean())/centers['3P'].std(ddof=0)
# <ipython-input-12-39d256dfe872>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centers['FG% Z'] = (centers['FG%'] - centers['FG%'].mean())/centers['FG%'].std(ddof=0)
# <ipython-input-12-39d256dfe872>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centers['FT% Z'] = (centers['FT%'] - centers['FT%'].mean())/centers['FT%'].std(ddof=0)
# <ipython-input-12-39d256dfe872>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centers['STL Z'] = (centers['STL'] - centers['STL'].mean())/centers['STL'].std(ddof=0)
# <ipython-input-12-39d256dfe872>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centers['BLK Z'] = (centers['BLK'] - centers['BLK'].mean())/centers['BLK'].std(ddof=0)
# <ipython-input-12-39d256dfe872>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centers['TOV Z'] = (centers['TOV'] - centers['TOV'].mean())/centers['TOV'].std(ddof=0)
#                   Name Pos  Age   Tm   PTS  TRB  AST  3P    FG%    FT%  ...  \
# 2         Steven Adams   C   24  OKC  1056  685   88   0  0.629  0.559  ...
# 3          Bam Adebayo   C   20  MIA   477  381  101   0  0.512  0.721  ...
# 6    LaMarcus Aldridge   C   32  SAS  1735  635  152  27  0.510  0.837  ...
# 7        Jarrett Allen   C   19  BRK   587  388   49   5  0.589  0.776  ...
# 38         Aron Baynes   C   31  BOS   482  434   93   3  0.471  0.756  ...
# ..                 ...  ..  ...  ...   ...  ...  ...  ..    ...    ...  ...
# 608     Nikola Vučević   C   27  ORL   939  523  191  64  0.475  0.819  ...
# 624         David West   C   37  GSW   495  238  138   3  0.571  0.759  ...
# 630   Hassan Whiteside   C   28  MIA   754  618   54   2  0.540  0.703  ...
# 657        Cody Zeller   C   25  CHO   233  177   31   2  0.545  0.718  ...
# 658       Tyler Zeller   C   28  TOT   441  305   47  10  0.560  0.722  ...
#
#      TOV     PTS Z     TRB Z     AST Z      3P Z     FG% Z     FT% Z  \
# 2    128  0.915953  1.013760 -0.280522 -0.671030  1.508380 -1.493487
# 3     66 -0.555518 -0.287898 -0.120864 -0.671030 -0.378951  0.096761
# 6    111  2.641564  0.799672  0.505485  0.009198 -0.411213  1.235457
# 7     82 -0.275964 -0.257926 -0.759494 -0.545062  0.863139  0.636660
# 38    80 -0.542811 -0.060964 -0.219115 -0.595449 -1.040324  0.440333
# ..   ...       ...       ...       ...       ...       ...       ...
# 608  109  0.618609  0.320113  0.984457  0.941362 -0.975800  1.058763
# 624   80 -0.509773 -0.900192  0.333546 -0.595449  0.572780  0.469782
# 630   92  0.148450  0.726882 -0.698088 -0.620643  0.072718 -0.079933
# 657   33 -1.175620 -1.161380 -0.980559 -0.620643  0.153373  0.067312
# 658   47 -0.647008 -0.613313 -0.784057 -0.419094  0.395338  0.106577
#
#         STL Z     BLK Z     TOV Z
# 2    2.441246  0.474908  0.654446
# 3   -0.399859 -0.654695 -0.470176
# 6    0.121010  0.841266  0.346082
# 7   -0.589266  0.780206 -0.179951
# 38  -0.873377 -0.349397 -0.216229
# ..        ...       ...       ...
# 608  0.736583 -0.013569  0.309804
# 624  0.310417  0.383319 -0.216229
# 630 -0.163100  0.963385  0.001440
# 657 -1.252191 -1.265291 -1.068765
# 658 -1.204839 -0.837874 -0.814818
#
# [63 rows x 22 columns]

# %%
guards["Z Total"] = guards['PTS Z'] + guards['TRB Z'] + guards['AST Z'] + guards['3P Z'] + guards['FG% Z'] + guards['FT% Z'] + guards['STL Z'] + guards['BLK Z'] - guards['TOV Z']
z_score_g = guards[['Name', "Pos", 'Z Total']].sort_values(by=["Z Total"], ascending=False)
z_score_g.reset_index()
z_score_g = z_score_g[['Name', 'Pos', 'Z Total']]
z_score_g.head(20)
# Out:
# <ipython-input-13-cba43723afe2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards["Z Total"] = guards['PTS Z'] + guards['TRB Z'] + guards['AST Z'] + guards['3P Z'] + guards['FG% Z'] + guards['FT% Z'] + guards['STL Z'] + guards['BLK Z'] - guards['TOV Z']
#                   Name Pos    Z Total
# 232       James Harden  SG  13.216737
# 472     Victor Oladipo  SG  12.148083
# 555        Ben Simmons  PG  11.236260
# 625  Russell Westbrook  PG  11.146417
# 269       Jrue Holiday  SG  11.126639
# 369     Damian Lillard  PG   9.337318
# 40        Bradley Beal  SG   8.593904
# 376         Kyle Lowry  PG   8.403766
# 35         Will Barton  SG   8.391849
# 613       Kemba Walker  PG   7.961098
# 57        Eric Bledsoe  PG   7.911154
# 395        CJ McCollum  SG   7.447564
# 588      Klay Thompson  SG   7.294734
# 488         Chris Paul  PG   7.213743
# 146      Stephen Curry  PG   7.031098
# 93        Jimmy Butler  SG   6.694923
# 420   Donovan Mitchell  SG   6.273182
# 292       Kyrie Irving  PG   6.157348
# 445       Jamal Murray  PG   6.137448
# 156      DeMar DeRozan  SG   6.111115

# %%
forwards["Z Total"] = forwards['PTS Z'] + forwards['TRB Z'] + forwards['AST Z'] + forwards['3P Z'] + forwards['FG% Z'] + forwards['FT% Z'] + forwards['STL Z'] + forwards['BLK Z'] - forwards['TOV Z']
z_score_f = forwards[['Name', "Pos", 'Z Total']].sort_values(by=["Z Total"], ascending=False)
z_score_f.reset_index()
z_score_f = z_score_f[['Name', 'Pos', 'Z Total']]
z_score_f.head(20)
# Out:
# <ipython-input-14-bd069fa40c06>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forwards["Z Total"] = forwards['PTS Z'] + forwards['TRB Z'] + forwards['AST Z'] + forwards['3P Z'] + forwards['FG% Z'] + forwards['FT% Z'] + forwards['STL Z'] + forwards['BLK Z'] - forwards['TOV Z']
#                       Name Pos    Z Total
# 148          Anthony Davis  PF  15.639902
# 303           LeBron James  PF  13.699060
# 171           Kevin Durant  SF  11.195380
# 15   Giannis Antetokounmpo  PF  11.100093
# 209            Paul George  SF   9.368898
# 505            Otto Porter  SF   7.979963
# 135       Robert Covington  SF   7.778418
# 411        Khris Middleton  SF   7.643993
# 223         Draymond Green  PF   6.788676
# 240          Tobias Harris  PF   6.514651
# 525        Josh Richardson  SF   6.155704
# 289             Joe Ingles  SF   5.756785
# 212             Taj Gibson  PF   4.713406
# 575           Jayson Tatum  SF   4.613760
# 284            Serge Ibaka  PF   4.189424
# 543            Dario Šarić  PF   4.075385
# 511         Taurean Prince  SF   4.051864
# 12           Kyle Anderson  SF   3.678475
# 123           John Collins  PF   3.411639
# 387        Lauri Markkanen  PF   3.287108

# %%
centers["Z Total"] = centers['PTS Z'] + centers['TRB Z'] + centers['AST Z'] + centers['3P Z'] + centers['FG% Z'] + centers['FT% Z'] + centers['STL Z'] + centers['BLK Z'] - centers['TOV Z']
z_score_c = centers[['Name', "Pos", 'Z Total']].sort_values(by=["Z Total"], ascending=False)
z_score_c.reset_index()
z_score_c = z_score_c[['Name', 'Pos', 'Z Total']]
z_score_c.head(20)
# Out:
# <ipython-input-15-19523b22452f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centers["Z Total"] = centers['PTS Z'] + centers['TRB Z'] + centers['AST Z'] + centers['3P Z'] + centers['FG% Z'] + centers['FT% Z'] + centers['STL Z'] + centers['BLK Z'] - centers['TOV Z']
#                    Name Pos    Z Total
# 592  Karl-Anthony Towns   C  11.608833
# 324        Nikola Jokić   C  10.595134
# 168      Andre Drummond   C   7.853436
# 206          Marc Gasol   C   5.814829
# 6     LaMarcus Aldridge   C   5.396356
# 278          Al Horford   C   5.337372
# 134    DeMarcus Cousins   C   4.577000
# 103        Clint Capela   C   4.459467
# 460       Dirk Nowitzki   C   4.345107
# 177         Joel Embiid   C   3.619539
# 375          Kevin Love   C   3.365218
# 608      Nikola Vučević   C   3.360715
# 2          Steven Adams   C   3.254763
# 280       Dwight Howard   C   2.665453
# 336         Enes Kanter   C   2.173486
# 598   Jonas Valančiūnas   C   2.042935
# 595        Myles Turner   C   1.891326
# 466        Kyle O'Quinn   C   1.824348
# 187      Derrick Favors   C   1.812070
# 508       Dwight Powell   C   1.640010

# %%
z_score_g.to_csv("output/guards_2017")

# %%
z_score_f.to_csv("output/forwards_2017")

# %%
z_score_c.to_csv("output/centers_2017")
